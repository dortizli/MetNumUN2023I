# %% [markdown]
# <a href="https://colab.research.google.com/github/dortizli/MetNumUN2023I/blob/main/LAB3/dortizli_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.linkedin.com/in/david-felipe-ortiz-linares-38a07326a/recent-activity/

# %% [markdown]
# ![IBM PY0101EN Certificate _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![IBM DA0101EN Certificate Data Analysis with Python _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![IBM DV0101EN Data Visualization with Python Certificate _ Cognitive Class_page-0001.jpg](data:image/jpeg;base64,...)
